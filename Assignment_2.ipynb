# %%
## 1. Bubble Sort

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

arr = [5, 2, 9, 1, 5, 6]
print("Bubble Sort:", bubble_sort(arr))
# Out:
# Bubble Sort: [1, 2, 5, 5, 6, 9]

# %%
## 2. Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i+1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

arr = [64, 25, 12, 22, 11]
print("Selection Sort:", selection_sort(arr))
# Out:
# Selection Sort: [11, 12, 22, 25, 64]

# %%
## 3. Insertion Sort

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1

        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1

        arr[j + 1] = key
    return arr

arr = [12, 11, 13, 5, 6]
print("Insertion Sort:", insertion_sort(arr))
# Out:
# Insertion Sort: [5, 6, 11, 12, 13]

# %%
## 4. Quadratic Equation Solver

# %%
import math

a = 1
b = -3
c = 2

d = b**2 - 4*a*c

if d > 0:
    root1 = (-b + math.sqrt(d)) / (2*a)
    root2 = (-b - math.sqrt(d)) / (2*a)
    print("Real roots:", root1, root2)
elif d == 0:
    root = -b / (2*a)
    print("Equal roots:", root)
else:
    real = -b / (2*a)
    imag = math.sqrt(-d) / (2*a)
    print("Complex roots:", real, "+ i", imag)
# Out:
# Real roots: 2.0 1.0

# %%
## 5. Merge Sort (Divide & Conquer)

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr)//2
        left = arr[:mid]
        right = arr[mid:]

        merge_sort(left)
        merge_sort(right)

        i = j = k = 0

        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
            k += 1

        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1

    return arr

arr = [38, 27, 43, 3, 9, 82, 10]
print("Merge Sort:", merge_sort(arr))
# Out:
# Merge Sort: [3, 9, 10, 27, 38, 43, 82]

# %%
## 6. Performance Comparison (Merge vs Bubble)

# %%
import time

arr = [5, 2, 9, 1, 5, 6, 7, 3, 8]

# Bubble Sort Time
start = time.time()
bubble_sort(arr.copy())
end = time.time()
print("Bubble Sort Time:", end - start)

# Merge Sort Time
start = time.time()
merge_sort(arr.copy())
end = time.time()
print("Merge Sort Time:", end - start)
# Out:
# Bubble Sort Time: 0.00015592575073242188
# Merge Sort Time: 0.00011801719665527344
