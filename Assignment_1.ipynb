# %%
## 1. Array Swap Program

# %%
arr = [10, 20, 30, 40]
i, j = 1, 2
arr[i], arr[j] = arr[j], arr[i]
print("After swap:", arr)
# Out:
# After swap: [10, 30, 20, 40]

# %%
## 2. Array Split Program

# %%
arr = [1, 2, 3, 4, 5, 6]
mid = len(arr) // 2

first_part = arr[:mid]
second_part = arr[mid:]

print("First part:", first_part)
print("Second part:", second_part)
# Out:
# First part: [1, 2, 3]
# Second part: [4, 5, 6]

# %%
## 3. Calculator using Functions

# %%
def add(a, b):
    return a + b

def sub(a, b):
    return a - b

def mul(a, b):
    return a * b

def div(a, b):
    return a / b

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition:", add(a, b))
print("Subtraction:", sub(a, b))
print("Multiplication:", mul(a, b))
print("Division:", div(a, b))
# Out:
# Enter first number: 10
# Enter second number: 20
# Addition: 30
# Subtraction: -10
# Multiplication: 200
# Division: 0.5

# %%
## 4. Discount Calculator

# %%
price = float(input("Enter price: "))
discount = float(input("Enter discount %: "))
final_price = price - (price * discount / 100)

print("Final price:", final_price)
# Out:
# Enter price: 1000
# Enter discount %: 15
# Final price: 850.0

# %%
## 5. Grade Calculator

# %%
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade: A")
elif marks >= 75:
    print("Grade: B")
elif marks >= 50:
    print("Grade: C")
else:
    print("Fail")
# Out:
# Enter marks: 80
# Grade: B

# %%
## 6. Odd/Even Check

# %%
num = int(input("Enter number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter number: 3
# Odd
