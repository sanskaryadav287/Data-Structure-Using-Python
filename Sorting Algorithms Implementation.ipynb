# %% [markdown]
# # Sorting Techniques Practice :
#
# **Here you will practice different sorting methods including selection sort, insertion sort, and bubble
# sort. You will also solve a quadratic equation, demonstrate the divide and conquer strategy, and
# implement merge sort while comparing its performance with bubble sort.**

# %% [markdown]
# **(A). Bubble Sort :-**

# %%
def bubble_sort(arr):
  n = len(arr)
  for i in range(n):
    for j in range(0, n-i-1):
      if arr[j] > arr[j + 1]:
        arr[j], arr[j + 1] = arr[j + 1], arr[j]
  return arr

array = [15,7,56,89,41,23]
print("Sorted array:",bubble_sort(array))
# Out:
# Sorted array: [7, 15, 23, 41, 56, 89]

# %% [markdown]
# **(B). Selection Sort :-**

# %%
def selection_sort(arr):
  n = len(arr)
  for i in range(n):
    min_index = i
    for j in range(i+1, n):
      if arr[j] < arr[min_index]:
        min_index = j
    arr[i], arr[min_index] = arr[min_index], arr[i]
  return arr

array = [15,13,46,75,1,6]
print("Sorted array:",selection_sort(array))
# Out:
# Sorted array: [1, 6, 13, 15, 46, 75]

# %% [markdown]
# **(C). Insertion Sort :-**

# %%
def insertion_sort(arr):
  n = len(arr)
  for i in range (1,n):
    key = arr[i]
    j = i - 1

    while j >= 0 and key < arr[j]:
      arr[j + 1] = arr[j]
      j -= 1
    arr[j + 1] = key
  return arr

array = [15,19,14,18,16]
print("Sorted array:", insertion_sort(array))
# Out:
# Sorted array: [14, 15, 16, 18, 19]

# %% [markdown]
# **(D). Divide and Conquer :-**

# %% [markdown]
# **(i). Merge Sort :**

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2

        # Divide
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        # Conquer
        i = j = k = 0

        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1

    return arr

print("Merge Sort:", merge_sort([38, 27, 43, 3, 9, 82, 10]))
# Out:
# Merge Sort: [3, 9, 10, 27, 38, 43, 82]

# %% [markdown]
# **(ii). Quick Sort :**

# %%
def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1

    for j in range(low, high):

        if arr[j] <= pivot:
            i += 1

            arr[i], arr[j] = arr[j], arr[i]

    arr[i + 1], arr[high] = arr[high], arr[i + 1]

    return i + 1

def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)

        quick_sort(arr, low, pi - 1)

        quick_sort(arr, pi + 1, high)

if __name__ == "__main__":
    my_array = [60, 20, 80, 10, 90, 30, 50, 70, 40]
    print("Original Array:", my_array)

    quick_sort(my_array, 0, len(my_array) - 1)

    print("Sorted Array:  ", my_array)
# Out:
# Original Array: [60, 20, 80, 10, 90, 30, 50, 70, 40]
# Sorted Array:   [10, 20, 30, 40, 50, 60, 70, 80, 90]
